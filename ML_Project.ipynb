# %% [markdown]
# <a href="https://colab.research.google.com/github/SheidaEmdadi/ML_Final/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)

# %%
import numpy as np
import scipy.sparse as sp
import time
import random
import pandas as pd

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.nn import GCNConv
from torch_geometric.utils import to_dense_adj
from pygod.utils import load_data

from sklearn.metrics import  roc_auc_score

from IPython.display import display

import matplotlib as mpl

# %% [markdown]
# #Helper Function

# %%
def _aug_random_edge(nb_nodes, edge_index, perturb_percent=0.2, self_loop = True):


    total_edges = edge_index.shape[1]
    avg_degree = int(total_edges/nb_nodes)


    edge_dict = {}
    for i in range(nb_nodes):
        edge_dict[i] = set()

    for edge in edge_index:
        i,j = edge[0],edge[1]
        i = i.item()
        j = j.item()
        edge_dict[i].add(j)
        edge_dict[j].add(i)


    for i in range(nb_nodes):

            d = len(edge_dict[i])

            num_edge_to_drop = int(d * perturb_percent)

            node_list = list(edge_dict[i])
            num_edge_to_drop = min(num_edge_to_drop, d)
            sampled_nodes = random.sample(node_list, num_edge_to_drop)

            for j in sampled_nodes:
                edge_dict[i].discard(j)
                edge_dict[j].discard(i)

    node_list = [i for i in range(nb_nodes)]

    add_list = []
    for i in range(nb_nodes):

        d = len(edge_dict[i])
        num_edge_to_add = int(d * perturb_percent)

        sampled_nodes = random.sample(node_list, num_edge_to_add)
        for j in sampled_nodes:
            add_list.append((i,j))

    if self_loop:
        for i in range(nb_nodes):
            edge_dict[i].add(i)

    updated_edges = set()
    for i in range(nb_nodes):
        for j in edge_dict[i]:
            updated_edges.add((i,j))
            updated_edges.add((j,i))

    row = []
    col = []
    for edge in updated_edges:
        u = edge[0]
        v = edge[1]
        row.append(u)
        col.append(v)

    aug_edge_index = [row,col]
    aug_edge_index = torch.tensor(aug_edge_index)

    return aug_edge_index


def preprocess_features(features):

    features = features.squeeze()
    rowsum = np.array(features.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    features = r_mat_inv.dot(features)
    return features

# %% [markdown]
# #MLP

# %%
class MLP(nn.Module):
    def __init__(self, num_layers, input_dim, hidden_dim, output_dim):

        super(MLP, self).__init__()

        self.num_layers = num_layers

        self.linears = torch.nn.ModuleList()
        self.batch_norms = torch.nn.ModuleList()

        self.linears.append(nn.Linear(input_dim, hidden_dim))
        for layer in range(num_layers - 2):
            self.linears.append(nn.Linear(hidden_dim, hidden_dim))
        self.linears.append(nn.Linear(hidden_dim, output_dim))

        for layer in range(num_layers - 1):
            self.batch_norms.append(nn.BatchNorm1d((hidden_dim)))

    def forward(self, x):
            h = x
            for layer in range(self.num_layers - 1):
                h = self.linears[layer](h)

                if len(h.shape) > 2:
                    h = torch.transpose(h, 0, 1)
                    h = torch.transpose(h, 1, 2)


                if len(h.shape) > 2:
                    h = torch.transpose(h, 1, 2)
                    h = torch.transpose(h, 0, 1)

                h = F.relu(h)

            return self.linears[self.num_layers - 1](h)

# %% [markdown]
# #GNN Model (GCN)

# %%
class GNN(nn.Module):
    def __init__(self, in_dim, out_dim):

        super(GNN, self).__init__()

        self.mlp0 = MLP(3, in_dim, out_dim, out_dim)

        self.graphconv1 = GCNConv(out_dim, out_dim, aggr='mean')


        self.mlp1 = nn.Linear(out_dim,1)
        self.sigmoid = nn.Sigmoid()
        self.relu = nn.ReLU()

    def forward(self, x, edge_index):
        h0 = self.mlp0(x)
        h1 = self.graphconv1(h0,edge_index)
        h2 = self.mlp1(h1)
        h2 = self.relu(h2)
        p = torch.exp(h2)
        return p

# %% [markdown]
# #Datasets

# %%
weibo = dict( dataset = "weibo",
                perturb_percent=  0.05,
                seed = 42,
                nb_epochs = 200,
                hidden_dim = 64,
                lr = 0.1,
                l2_coef = 100,
                self_loop = False,
                preprocess_feat = False
              )


reddit = dict( dataset = "reddit",
                perturb_percent=  0.05,
                seed = 10,
                nb_epochs = 100,
                hidden_dim = 16,
                lr = 0.001,
                l2_coef = 10.0,
                self_loop = True,
                preprocess_feat = True
              )


disney = dict( dataset = "disney",
                perturb_percent=  0.05,
                seed = 42,
                nb_epochs = 200,
                hidden_dim = 16,
                lr = 0.01,
                l2_coef = 0,
                self_loop = True,
                preprocess_feat = True
              )


books = dict( dataset = "books",
              perturb_percent=  0.05,
              seed = 10,
              nb_epochs = 100,
              hidden_dim = 16,
              lr = 0.01,
              l2_coef = 10,
              self_loop = True,
              preprocess_feat = True
            )

# %% [markdown]
# #Main

# %%
for i in range(4):

    dataset_name = [reddit ,disney, books, weibo]



    dataset_str = dataset_name[i]['dataset']
    perturb_percent = dataset_name[i]['perturb_percent']

    seed = dataset_name[i]['seed']
    if dataset_str == "disney":
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)

    nb_epochs = dataset_name[i]['nb_epochs']
    lr = dataset_name[i]['lr']
    l2_coef = dataset_name[i]['l2_coef']
    hidden_dim = dataset_name[i]['hidden_dim']
    self_loop = dataset_name[i]['self_loop']
    preprocess_feat = dataset_name[i]['preprocess_feat']


    print("_" * 100)
    print("dataset: " + dataset_name[i]['dataset'])
    print("_" * 100)



    num_neigh = 1

    data = load_data(dataset_str)
    edge_index = data.edge_index


    adj = to_dense_adj(edge_index).squeeze()
    features = data.x
    labels = data.y
    y = labels.bool()

    anomaly_nodes = np.nonzero(y)

    nb_nodes = features.shape[0]
    input_dim = features.shape[1]



    model = GNN(input_dim, hidden_dim)
    optimiser = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=l2_coef)


    if preprocess_feat:
        features = preprocess_features(features)




    start_time = time.time()
    mx_auc = 0

    aug_edge_indexes = []

    for i in range(num_neigh):
        aug_edge_index = _aug_random_edge(nb_nodes, edge_index, perturb_percent=perturb_percent, self_loop=self_loop)
        aug_edge_indexes.append(aug_edge_index)



    features = torch.FloatTensor(features[np.newaxis])


    losses = []

    for epoch in range(nb_epochs):

        model.train()
        optimiser.zero_grad()

        p_data = model(features, edge_index)
        loss = 0

        for i in range(num_neigh):

            aug_edge_index = aug_edge_indexes[i]

            shuffle_features = features
            idx = np.random.permutation(nb_nodes)
            shuffle_features = features[:, idx, :]


            p_neigh = model(shuffle_features, aug_edge_index)

            c_theta_j1 = p_neigh/p_data
            c_theta_j2 = p_data/p_neigh

            j1 = (c_theta_j1**2 + 2 * c_theta_j1).mean()
            j2 = (2 * c_theta_j2).mean()



            neigh_loss = j1 - j2
            neigh_loss = neigh_loss.mean()
            loss += neigh_loss

        loss = loss / num_neigh

        losses.append(loss)



        logits = p_data.squeeze().detach()
        auc_score = roc_auc_score(y_true = y.numpy(), y_score = logits.numpy()) * 100

        print("Epoch: ", epoch, " Loss: ", loss.item(), " AUC Score: ", auc_score)
        mx_auc = max(mx_auc, auc_score)

        loss.backward()
        optimiser.step()

    end_time = time.time()



    print("Maximum AUC: ", mx_auc)
    print("Required Time: ", end_time - start_time)
# Out:
# ____________________________________________________________________________________________________
# dataset: reddit
# ____________________________________________________________________________________________________
# Epoch:  0  Loss:  1.2658501863479614  AUC Score:  41.99129069411979
# Epoch:  1  Loss:  1.2586008310317993  AUC Score:  41.99116203333447
# Epoch:  2  Loss:  1.2513861656188965  AUC Score:  41.99127782804125
# Epoch:  3  Loss:  1.2442251443862915  AUC Score:  41.99112343509887
# Epoch:  4  Loss:  1.2371094226837158  AUC Score:  41.97672629322102
# Epoch:  5  Loss:  1.230026364326477  AUC Score:  41.97581280164522
# Epoch:  6  Loss:  1.2229855060577393  AUC Score:  41.97522096203272
# Epoch:  7  Loss:  1.2160072326660156  AUC Score:  41.975182363797124
# Epoch:  8  Loss:  1.2091035842895508  AUC Score:  41.975143765561526
# Epoch:  9  Loss:  1.202283501625061  AUC Score:  41.97511803340445
# Epoch:  10  Loss:  1.1955606937408447  AUC Score:  41.975118033404456
# Epoch:  11  Loss:  1.188948154449463  AUC Score:  41.97509230124739
# Epoch:  12  Loss:  1.182457685470581  AUC Score:  41.97525956026832
# Epoch:  13  Loss:  1.176095724105835  AUC Score:  41.97527242634685
# Epoch:  14  Loss:  1.1698650121688843  AUC Score:  41.97556834615309
# Epoch:  15  Loss:  1.1637672185897827  AUC Score:  41.97565840870282
# Epoch:  16  Loss:  1.1578031778335571  AUC Score:  41.97552974791749
# Epoch:  17  Loss:  1.1519702672958374  AUC Score:  41.97572273909549
# Epoch:  18  Loss:  1.14626944065094  AUC Score:  41.975774203409614
# Epoch:  19  Loss:  1.1406981945037842  AUC Score:  41.9760057928232
# Epoch:  20  Loss:  1.1352555751800537  AUC Score:  41.975774203409614
# Epoch:  21  Loss:  1.1299383640289307  AUC Score:  41.97582566772374
# Epoch:  22  Loss:  1.1247434616088867  AUC Score:  41.97591573027347
# Epoch:  23  Loss:  1.119667649269104  AUC Score:  41.97599292674467
# Epoch:  24  Loss:  1.1147090196609497  AUC Score:  41.97634031086505
# Epoch:  25  Loss:  1.1098642349243164  AUC Score:  41.976481837728905
# Epoch:  26  Loss:  1.1051322221755981  AUC Score:  41.97625024831532
# Epoch:  27  Loss:  1.100512981414795  AUC Score:  41.97673915929955
# Epoch:  28  Loss:  1.0960054397583008  AUC Score:  41.976623364592754
# Epoch:  29  Loss:  1.0916082859039307  AUC Score:  41.97673915929955
# Epoch:  30  Loss:  1.087320327758789  AUC Score:  41.9764432394933
# Epoch:  31  Loss:  1.0831396579742432  AUC Score:  41.97667482890689
# Epoch:  32  Loss:  1.0790637731552124  AUC Score:  41.976919284399
# Epoch:  33  Loss:  1.0750904083251953  AUC Score:  41.9774725257759
# Epoch:  34  Loss:  1.071218729019165  AUC Score:  41.977729847346545
# Epoch:  35  Loss:  1.0674492120742798  AUC Score:  41.977678383032426
# Epoch:  36  Loss:  1.0637800693511963  AUC Score:  41.97816729401666
# Epoch:  37  Loss:  1.0602102279663086  AUC Score:  41.978540410294094
# Epoch:  38  Loss:  1.0567376613616943  AUC Score:  41.97878486578621
# Epoch:  39  Loss:  1.0533610582351685  AUC Score:  41.97852754421557
# Epoch:  40  Loss:  1.0500775575637817  AUC Score:  41.97878486578622
# Epoch:  41  Loss:  1.046885371208191  AUC Score:  41.977858508131874
# Epoch:  42  Loss:  1.04378342628479  AUC Score:  41.97736959714764
# Epoch:  43  Loss:  1.0407687425613403  AUC Score:  41.97725380244085
# Epoch:  44  Loss:  1.037840485572815  AUC Score:  41.97891352657154
# Epoch:  45  Loss:  1.034997582435608  AUC Score:  41.979248044613385
# Epoch:  46  Loss:  1.0322375297546387  AUC Score:  41.98043172383837
# Epoch:  47  Loss:  1.0295592546463013  AUC Score:  41.9811522242362
# Epoch:  48  Loss:  1.0269618034362793  AUC Score:  41.98160253698482
# Epoch:  49  Loss:  1.024444580078125  AUC Score:  41.98362251131444
# Epoch:  50  Loss:  1.0220072269439697  AUC Score:  41.984613199361426
# Epoch:  51  Loss:  1.019649624824524  AUC Score:  41.98577114642936
# Epoch:  52  Loss:  1.017371654510498  AUC Score:  41.97006166454119
# Epoch:  53  Loss:  1.0151726007461548  AUC Score:  41.970473379054226
# Epoch:  54  Loss:  1.0130506753921509  AUC Score:  41.963101116055114
# Epoch:  55  Loss:  1.01100492477417  AUC Score:  41.96383448253147
# Epoch:  56  Loss:  1.009035587310791  AUC Score:  41.97001020022706
# Epoch:  57  Loss:  1.007138729095459  AUC Score:  41.97465485457728
# Epoch:  58  Loss:  1.0053147077560425  AUC Score:  42.10296825578176
# Epoch:  59  Loss:  1.0035604238510132  AUC Score:  42.03026204599469
# Epoch:  60  Loss:  1.001875400543213  AUC Score:  42.120183068858225
# Epoch:  61  Loss:  1.0002573728561401  AUC Score:  42.98080792797466
# Epoch:  62  Loss:  0.9987063407897949  AUC Score:  58.4955488514709
# Epoch:  63  Loss:  0.997218132019043  AUC Score:  58.39442147420557
# Epoch:  64  Loss:  0.9957931041717529  AUC Score:  58.35297983525243
# Epoch:  65  Loss:  0.9944291114807129  AUC Score:  58.32148367500491
# Epoch:  66  Loss:  0.9931249618530273  AUC Score:  58.34755035011172
# Epoch:  67  Loss:  0.9918792247772217  AUC Score:  58.3474988857976
# Epoch:  68  Loss:  0.9906892776489258  AUC Score:  58.33947045279333
# Epoch:  69  Loss:  0.9895532131195068  AUC Score:  58.326012534648356
# Epoch:  70  Loss:  0.9884705543518066  AUC Score:  58.32590960602009
# Epoch:  71  Loss:  0.9874374866485596  AUC Score:  58.32246149697339
# Epoch:  72  Loss:  0.9864535331726074  AUC Score:  58.31924497734027
# Epoch:  73  Loss:  0.9855170249938965  AUC Score:  58.31883326282722
# Epoch:  74  Loss:  0.9846265316009521  AUC Score:  58.31963095969625
# Epoch:  75  Loss:  0.9837813377380371  AUC Score:  58.3191806469476
# Epoch:  76  Loss:  0.9829785823822021  AUC Score:  58.31719927085359
# Epoch:  77  Loss:  0.9822182655334473  AUC Score:  58.317778244387554
# Epoch:  78  Loss:  0.9814999103546143  AUC Score:  58.31651736869138
# Epoch:  79  Loss:  0.9808206558227539  AUC Score:  58.31743086026718
# Epoch:  80  Loss:  0.9801807403564453  AUC Score:  58.31593839515741
# Epoch:  81  Loss:  0.9795780181884766  AUC Score:  58.316929083204414
# Epoch:  82  Loss:  0.9790120124816895  AUC Score:  58.317070610068264
# Epoch:  83  Loss:  0.9784817695617676  AUC Score:  58.294464910086695
# Epoch:  84  Loss:  0.9779856204986572  AUC Score:  58.2938344722386
# Epoch:  85  Loss:  0.9775247573852539  AUC Score:  58.28921555004545
# Epoch:  86  Loss:  0.9770998954772949  AUC Score:  58.31210430375473
# Epoch:  87  Loss:  0.9767065048217773  AUC Score:  58.312580348660425
# Epoch:  88  Loss:  0.9763414859771729  AUC Score:  58.312490286110716
# Epoch:  89  Loss:  0.9760053157806396  AUC Score:  58.311075017472135
# Epoch:  90  Loss:  0.9756970405578613  AUC Score:  58.26541330476034
# Epoch:  91  Loss:  0.9754195213317871  AUC Score:  58.26425535769242
# Epoch:  92  Loss:  0.975172758102417  AUC Score:  58.26730461830463
# Epoch:  93  Loss:  0.974952220916748  AUC Score:  58.26668704653506
# Epoch:  94  Loss:  0.974754810333252  AUC Score:  58.266764243006264
# Epoch:  95  Loss:  0.9745771884918213  AUC Score:  58.26477000083372
# Epoch:  96  Loss:  0.9744172096252441  AUC Score:  58.264203893378294
# Epoch:  97  Loss:  0.9742748737335205  AUC Score:  58.26483433122638
# Epoch:  98  Loss:  0.9741497039794922  AUC Score:  58.26419102729975
# Epoch:  99  Loss:  0.9740438461303711  AUC Score:  58.263869375336455
# Maximum AUC:  58.4955488514709
# Required Time:  26.720743417739868
# ____________________________________________________________________________________________________
# dataset: disney
# ____________________________________________________________________________________________________
# Epoch:  0  Loss:  1.012944221496582  AUC Score:  75.28248587570621
# Epoch:  1  Loss:  0.9874446392059326  AUC Score:  39.97175141242938
# Epoch:  2  Loss:  0.9658653736114502  AUC Score:  36.440677966101696
# Epoch:  3  Loss:  0.9105026721954346  AUC Score:  31.14406779661017
# Epoch:  4  Loss:  0.817488431930542  AUC Score:  26.906779661016948
# Epoch:  5  Loss:  0.7962486743927002  AUC Score:  29.09604519774011
# Epoch:  6  Loss:  0.7856793403625488  AUC Score:  28.389830508474574
# Epoch:  7  Loss:  0.7431492805480957  AUC Score:  32.909604519774014
# Epoch:  8  Loss:  0.6755564212799072  AUC Score:  30.93220338983051
# Epoch:  9  Loss:  0.5836212635040283  AUC Score:  29.096045197740118
# Epoch:  10  Loss:  0.5769994258880615  AUC Score:  27.04802259887006
# Epoch:  11  Loss:  0.5556321144104004  AUC Score:  27.04802259887006
# Epoch:  12  Loss:  0.499675989151001  AUC Score:  27.04802259887006
# Epoch:  13  Loss:  0.41173291206359863  AUC Score:  27.04802259887006
# Epoch:  14  Loss:  0.30864977836608887  AUC Score:  26.836158192090398
# Epoch:  15  Loss:  0.2651686668395996  AUC Score:  26.55367231638418
# Epoch:  16  Loss:  0.17571401596069336  AUC Score:  26.412429378531076
# Epoch:  17  Loss:  0.12929058074951172  AUC Score:  27.04802259887006
# Epoch:  18  Loss:  0.06556129455566406  AUC Score:  27.04802259887006
# Epoch:  19  Loss:  -0.03700852394104004  AUC Score:  27.04802259887006
# Epoch:  20  Loss:  -0.1423332691192627  AUC Score:  26.271186440677962
# Epoch:  21  Loss:  -0.23428726196289062  AUC Score:  26.271186440677962
# Epoch:  22  Loss:  -0.3334972858428955  AUC Score:  27.04802259887006
# Epoch:  23  Loss:  -0.4370083808898926  AUC Score:  27.04802259887006
# Epoch:  24  Loss:  -0.5706291198730469  AUC Score:  26.129943502824858
# Epoch:  25  Loss:  -0.6944069862365723  AUC Score:  23.870056497175142
# Epoch:  26  Loss:  -0.8301076889038086  AUC Score:  26.906779661016945
# Epoch:  27  Loss:  -0.9716365337371826  AUC Score:  26.906779661016948
# Epoch:  28  Loss:  -1.1048529148101807  AUC Score:  26.906779661016948
# Epoch:  29  Loss:  -1.3003038167953491  AUC Score:  29.66101694915254
# Epoch:  30  Loss:  -1.3852927684783936  AUC Score:  28.67231638418079
# Epoch:  31  Loss:  -1.651236653327942  AUC Score:  28.8135593220339
# Epoch:  32  Loss:  -1.7637289762496948  AUC Score:  26.906779661016948
# Epoch:  33  Loss:  -1.9267172813415527  AUC Score:  26.906779661016948
# Epoch:  34  Loss:  -2.229053020477295  AUC Score:  26.906779661016948
# Epoch:  35  Loss:  -2.6646313667297363  AUC Score:  28.813559322033893
# Epoch:  36  Loss:  -2.799769163131714  AUC Score:  29.378531073446325
# Epoch:  37  Loss:  -3.3489863872528076  AUC Score:  27.82485875706215
# Epoch:  38  Loss:  -3.592658519744873  AUC Score:  26.906779661016948
# Epoch:  39  Loss:  -4.087413311004639  AUC Score:  26.906779661016948
# Epoch:  40  Loss:  -4.583049774169922  AUC Score:  28.53107344632768
# Epoch:  41  Loss:  -5.357825756072998  AUC Score:  29.661016949152547
# Epoch:  42  Loss:  -6.007308483123779  AUC Score:  28.389830508474578
# Epoch:  43  Loss:  -6.548410415649414  AUC Score:  26.906779661016948
# Epoch:  44  Loss:  -7.410216331481934  AUC Score:  26.906779661016948
# Epoch:  45  Loss:  -8.971147537231445  AUC Score:  28.24858757062147
# Epoch:  46  Loss:  -8.845566749572754  AUC Score:  27.54237288135593
# Epoch:  47  Loss:  -10.98519515991211  AUC Score:  27.683615819209038
# Epoch:  48  Loss:  -12.857772827148438  AUC Score:  27.04802259887006
# Epoch:  49  Loss:  -14.22858715057373  AUC Score:  27.04802259887006
# Epoch:  50  Loss:  -17.246471405029297  AUC Score:  27.04802259887006
# Epoch:  51  Loss:  -22.14351463317871  AUC Score:  26.0593220338983
# Epoch:  52  Loss:  -24.999279022216797  AUC Score:  27.11864406779661
# Epoch:  53  Loss:  -29.625659942626953  AUC Score:  27.04802259887006
# Epoch:  54  Loss:  -34.614891052246094  AUC Score:  27.04802259887006
# Epoch:  55  Loss:  -44.99877166748047  AUC Score:  27.04802259887006
# Epoch:  56  Loss:  -43.933074951171875  AUC Score:  26.9774011299435
# Epoch:  57  Loss:  -61.36824035644531  AUC Score:  26.69491525423729
# Epoch:  58  Loss:  -75.021240234375  AUC Score:  27.04802259887006
# Epoch:  59  Loss:  -84.21367645263672  AUC Score:  27.04802259887006
# Epoch:  60  Loss:  -107.29270935058594  AUC Score:  27.04802259887006
# Epoch:  61  Loss:  -155.42442321777344  AUC Score:  27.04802259887006
# Epoch:  62  Loss:  -134.03640747070312  AUC Score:  26.69491525423729
# Epoch:  63  Loss:  -197.70394897460938  AUC Score:  26.9774011299435
# Epoch:  64  Loss:  -310.3606262207031  AUC Score:  27.04802259887006
# Epoch:  65  Loss:  -363.8440856933594  AUC Score:  26.906779661016948
# Epoch:  66  Loss:  -497.2916259765625  AUC Score:  26.906779661016948
# Epoch:  67  Loss:  -651.6199340820312  AUC Score:  27.11864406779661
# Epoch:  68  Loss:  -874.822998046875  AUC Score:  26.906779661016948
# Epoch:  69  Loss:  -1098.0198974609375  AUC Score:  26.906779661016948
# Epoch:  70  Loss:  -1592.5965576171875  AUC Score:  27.04802259887006
# Epoch:  71  Loss:  -1454.872802734375  AUC Score:  27.11864406779661
# Epoch:  72  Loss:  -3035.352783203125  AUC Score:  25.635593220338983
# Epoch:  73  Loss:  -3809.0078125  AUC Score:  27.04802259887006
# Epoch:  74  Loss:  -5452.6826171875  AUC Score:  27.04802259887006
# Epoch:  75  Loss:  -4937.11767578125  AUC Score:  26.129943502824858
# Epoch:  76  Loss:  -10136.71484375  AUC Score:  27.04802259887006
# Epoch:  77  Loss:  -13519.4462890625  AUC Score:  27.04802259887006
# Epoch:  78  Loss:  -19702.3828125  AUC Score:  27.04802259887006
# Epoch:  79  Loss:  -23801.1328125  AUC Score:  27.25988700564972
# Epoch:  80  Loss:  -40140.70703125  AUC Score:  26.906779661016948
# Epoch:  81  Loss:  -51079.5546875  AUC Score:  26.906779661016948
# Epoch:  82  Loss:  -80472.375  AUC Score:  26.906779661016948
# Epoch:  83  Loss:  -99974.5703125  AUC Score:  26.906779661016948
# Epoch:  84  Loss:  -182380.75  AUC Score:  26.906779661016948
# Epoch:  85  Loss:  -257964.234375  AUC Score:  26.906779661016948
# Epoch:  86  Loss:  -437902.96875  AUC Score:  26.906779661016948
# Epoch:  87  Loss:  -395005.25  AUC Score:  27.966101694915256
# Epoch:  88  Loss:  -779727.4375  AUC Score:  26.906779661016948
# Epoch:  89  Loss:  -844327.125  AUC Score:  26.906779661016948
# Epoch:  90  Loss:  -1173800.625  AUC Score:  26.906779661016948
# Epoch:  91  Loss:  -2226673.0  AUC Score:  26.906779661016948
# Epoch:  92  Loss:  -3936890.75  AUC Score:  26.906779661016948
# Epoch:  93  Loss:  -6963765.0  AUC Score:  26.906779661016948
# Epoch:  94  Loss:  -11964916.0  AUC Score:  26.906779661016948
# Epoch:  95  Loss:  5887016.0  AUC Score:  26.906779661016948
# Epoch:  96  Loss:  -16713803.0  AUC Score:  26.906779661016948
# Epoch:  97  Loss:  -11155755.0  AUC Score:  27.04802259887006
# Epoch:  98  Loss:  -8265663.0  AUC Score:  27.04802259887006
# Epoch:  99  Loss:  -6832196.5  AUC Score:  27.04802259887006
# Epoch:  100  Loss:  -6188442.5  AUC Score:  28.10734463276836
# Epoch:  101  Loss:  -6079874.0  AUC Score:  31.285310734463273
# Epoch:  102  Loss:  -6454311.0  AUC Score:  31.285310734463273
# Epoch:  103  Loss:  -7417744.0  AUC Score:  31.285310734463273
# Epoch:  104  Loss:  -9308742.0  AUC Score:  31.285310734463273
# Epoch:  105  Loss:  -12996678.0  AUC Score:  31.285310734463273
# Epoch:  106  Loss:  -20923396.0  AUC Score:  31.285310734463273
# Epoch:  107  Loss:  -41442784.0  AUC Score:  31.285310734463273
# Epoch:  108  Loss:  -111712080.0  AUC Score:  27.04802259887006
# Epoch:  109  Loss:  -442779936.0  AUC Score:  27.04802259887006
# Epoch:  110  Loss:  -1828362240.0  AUC Score:  27.04802259887006
# Epoch:  111  Loss:  2773905920.0  AUC Score:  26.83615819209039
# Epoch:  112  Loss:  22260624.0  AUC Score:  27.118644067796605
# Epoch:  113  Loss:  -360609.0  AUC Score:  27.25988700564972
# Epoch:  114  Loss:  -141329.0  AUC Score:  27.11864406779661
# Epoch:  115  Loss:  -35130.6328125  AUC Score:  27.25988700564972
# Epoch:  116  Loss:  -10020.3623046875  AUC Score:  27.25988700564972
# Epoch:  117  Loss:  -3507.9267578125  AUC Score:  26.836158192090398
# Epoch:  118  Loss:  -1471.229248046875  AUC Score:  26.69491525423729
# Epoch:  119  Loss:  -711.8528442382812  AUC Score:  26.271186440677962
# Epoch:  120  Loss:  -386.7174072265625  AUC Score:  25.988700564971758
# Epoch:  121  Loss:  -231.85275268554688  AUC Score:  25.847457627118644
# Epoch:  122  Loss:  -150.28106689453125  AUC Score:  25.70621468926554
# Epoch:  123  Loss:  -104.05384063720703  AUC Score:  25.423728813559322
# Epoch:  124  Loss:  -76.07682037353516  AUC Score:  25.282485875706218
# Epoch:  125  Loss:  -58.11863327026367  AUC Score:  25.141242937853107
# Epoch:  126  Loss:  -46.09380340576172  AUC Score:  25.141242937853107
# Epoch:  127  Loss:  -37.72200012207031  AUC Score:  25.141242937853107
# Epoch:  128  Loss:  -31.705982208251953  AUC Score:  25.282485875706218
# Epoch:  129  Loss:  -27.232524871826172  AUC Score:  25.141242937853107
# Epoch:  130  Loss:  -23.850982666015625  AUC Score:  25.141242937853107
# Epoch:  131  Loss:  -21.237796783447266  AUC Score:  25.21186440677966
# Epoch:  132  Loss:  -19.158781051635742  AUC Score:  25.282485875706218
# Epoch:  133  Loss:  -17.495595932006836  AUC Score:  25.282485875706218
# Epoch:  134  Loss:  -16.15183448791504  AUC Score:  25.282485875706218
# Epoch:  135  Loss:  -15.050012588500977  AUC Score:  25.282485875706218
# Epoch:  136  Loss:  -14.12901782989502  AUC Score:  25.635593220338983
# Epoch:  137  Loss:  -13.355321884155273  AUC Score:  25.49435028248588
# Epoch:  138  Loss:  -12.704446792602539  AUC Score:  25.423728813559322
# Epoch:  139  Loss:  -12.144529342651367  AUC Score:  25.423728813559322
# Epoch:  140  Loss:  -11.6749267578125  AUC Score:  25.28248587570621
# Epoch:  141  Loss:  -11.267807960510254  AUC Score:  25.28248587570621
# Epoch:  142  Loss:  -10.915669441223145  AUC Score:  25.141242937853104
# Epoch:  143  Loss:  -10.602363586425781  AUC Score:  25.21186440677966
# Epoch:  144  Loss:  -10.33084774017334  AUC Score:  25.07062146892655
# Epoch:  145  Loss:  -10.095699310302734  AUC Score:  25.0
# Epoch:  146  Loss:  -9.895356178283691  AUC Score:  24.999999999999996
# Epoch:  147  Loss:  -9.71196174621582  AUC Score:  24.999999999999996
# Epoch:  148  Loss:  -9.550599098205566  AUC Score:  24.929378531073446
# Epoch:  149  Loss:  -9.40388298034668  AUC Score:  24.999999999999996
# Epoch:  150  Loss:  -9.276239395141602  AUC Score:  24.717514124293785
# Epoch:  151  Loss:  -9.168377876281738  AUC Score:  24.858757062146893
# Epoch:  152  Loss:  -9.065604209899902  AUC Score:  24.78813559322034
# Epoch:  153  Loss:  -8.978416442871094  AUC Score:  24.78813559322034
# Epoch:  154  Loss:  -8.898689270019531  AUC Score:  24.505649717514125
# Epoch:  155  Loss:  -8.830591201782227  AUC Score:  24.576271186440678
# Epoch:  156  Loss:  -8.759900093078613  AUC Score:  24.646892655367232
# Epoch:  157  Loss:  -8.70822525024414  AUC Score:  24.646892655367232
# Epoch:  158  Loss:  -8.65445327758789  AUC Score:  24.576271186440678
# Epoch:  159  Loss:  -8.606881141662598  AUC Score:  24.646892655367232
# Epoch:  160  Loss:  -8.565374374389648  AUC Score:  24.646892655367232
# Epoch:  161  Loss:  -8.53339958190918  AUC Score:  24.646892655367232
# Epoch:  162  Loss:  -8.497513771057129  AUC Score:  24.646892655367232
# Epoch:  163  Loss:  -8.474347114562988  AUC Score:  24.646892655367232
# Epoch:  164  Loss:  -8.441438674926758  AUC Score:  24.646892655367232
# Epoch:  165  Loss:  -8.417036056518555  AUC Score:  24.646892655367232
# Epoch:  166  Loss:  -8.394545555114746  AUC Score:  24.646892655367232
# Epoch:  167  Loss:  -8.379316329956055  AUC Score:  24.646892655367232
# Epoch:  168  Loss:  -8.359992980957031  AUC Score:  24.646892655367232
# Epoch:  169  Loss:  -8.347654342651367  AUC Score:  24.646892655367232
# Epoch:  170  Loss:  -8.33201789855957  AUC Score:  24.646892655367232
# Epoch:  171  Loss:  -8.319536209106445  AUC Score:  24.646892655367232
# Epoch:  172  Loss:  -8.307547569274902  AUC Score:  24.646892655367232
# Epoch:  173  Loss:  -8.296829223632812  AUC Score:  24.646892655367232
# Epoch:  174  Loss:  -8.284245491027832  AUC Score:  24.646892655367232
# Epoch:  175  Loss:  -8.28278636932373  AUC Score:  24.646892655367232
# Epoch:  176  Loss:  -8.268383979797363  AUC Score:  24.646892655367232
# Epoch:  177  Loss:  -8.262194633483887  AUC Score:  24.646892655367232
# Epoch:  178  Loss:  -8.260065078735352  AUC Score:  24.646892655367232
# Epoch:  179  Loss:  -8.252373695373535  AUC Score:  24.646892655367232
# Epoch:  180  Loss:  -8.247953414916992  AUC Score:  24.576271186440675
# Epoch:  181  Loss:  -8.240650177001953  AUC Score:  24.576271186440675
# Epoch:  182  Loss:  -8.237103462219238  AUC Score:  24.576271186440675
# Epoch:  183  Loss:  -8.23405647277832  AUC Score:  24.576271186440675
# Epoch:  184  Loss:  -8.229552268981934  AUC Score:  24.576271186440675
# Epoch:  185  Loss:  -8.22607707977295  AUC Score:  24.576271186440675
# Epoch:  186  Loss:  -8.225458145141602  AUC Score:  24.576271186440675
# Epoch:  187  Loss:  -8.219965934753418  AUC Score:  24.576271186440675
# Epoch:  188  Loss:  -8.222381591796875  AUC Score:  24.576271186440675
# Epoch:  189  Loss:  -8.217329025268555  AUC Score:  24.576271186440675
# Epoch:  190  Loss:  -8.21402359008789  AUC Score:  24.576271186440675
# Epoch:  191  Loss:  -8.216594696044922  AUC Score:  24.505649717514125
# Epoch:  192  Loss:  -8.212406158447266  AUC Score:  24.576271186440675
# Epoch:  193  Loss:  -8.21565055847168  AUC Score:  24.576271186440675
# Epoch:  194  Loss:  -8.214179992675781  AUC Score:  24.576271186440675
# Epoch:  195  Loss:  -8.206523895263672  AUC Score:  24.576271186440675
# Epoch:  196  Loss:  -8.207536697387695  AUC Score:  24.576271186440675
# Epoch:  197  Loss:  -8.206897735595703  AUC Score:  24.576271186440675
# Epoch:  198  Loss:  -8.203085899353027  AUC Score:  24.576271186440675
# Epoch:  199  Loss:  -8.203539848327637  AUC Score:  24.576271186440675
# Maximum AUC:  75.28248587570621
# Required Time:  2.0069446563720703
# ____________________________________________________________________________________________________
# dataset: books
# ____________________________________________________________________________________________________
# Epoch:  0  Loss:  1.0  AUC Score:  50.0
# Epoch:  1  Loss:  1.0  AUC Score:  50.0
# Epoch:  2  Loss:  1.0  AUC Score:  50.0
# Epoch:  3  Loss:  1.0  AUC Score:  50.0
# Epoch:  4  Loss:  1.0  AUC Score:  50.0
# Epoch:  5  Loss:  1.0  AUC Score:  50.0
# Epoch:  6  Loss:  1.0  AUC Score:  50.0
# Epoch:  7  Loss:  1.0  AUC Score:  50.0
# Epoch:  8  Loss:  1.0  AUC Score:  50.0
# Epoch:  9  Loss:  1.0  AUC Score:  50.0
# Epoch:  10  Loss:  1.0  AUC Score:  50.0
# Epoch:  11  Loss:  1.0  AUC Score:  50.0
# Epoch:  12  Loss:  1.0  AUC Score:  50.0
# Epoch:  13  Loss:  1.0  AUC Score:  50.0
# Epoch:  14  Loss:  1.0  AUC Score:  50.0
# Epoch:  15  Loss:  1.0  AUC Score:  50.0
# Epoch:  16  Loss:  1.0  AUC Score:  50.0
# Epoch:  17  Loss:  1.0  AUC Score:  50.0
# Epoch:  18  Loss:  1.0  AUC Score:  50.0
# Epoch:  19  Loss:  1.002746343612671  AUC Score:  62.439619732785204
# Epoch:  20  Loss:  1.0014305114746094  AUC Score:  62.439619732785204
# Epoch:  21  Loss:  1.000408411026001  AUC Score:  62.44090441932168
# Epoch:  22  Loss:  0.9997267723083496  AUC Score:  37.56294964028777
# Epoch:  23  Loss:  0.9993720054626465  AUC Score:  37.56166495375128
# Epoch:  24  Loss:  0.999272346496582  AUC Score:  37.560380267214796
# Epoch:  25  Loss:  0.9993376731872559  AUC Score:  37.560380267214796
# Epoch:  26  Loss:  0.9994854927062988  AUC Score:  37.560380267214796
# Epoch:  27  Loss:  0.9996528625488281  AUC Score:  37.560380267214796
# Epoch:  28  Loss:  0.9998056888580322  AUC Score:  37.56294964028777
# Epoch:  29  Loss:  0.9999339580535889  AUC Score:  37.55781089414183
# Epoch:  30  Loss:  1.0000348091125488  AUC Score:  62.47559095580678
# Epoch:  31  Loss:  1.0001083612442017  AUC Score:  62.45118191161356
# Epoch:  32  Loss:  1.000159502029419  AUC Score:  62.43576567317574
# Epoch:  33  Loss:  1.0001927614212036  AUC Score:  62.439619732785204
# Epoch:  34  Loss:  1.0002113580703735  AUC Score:  62.439619732785204
# Epoch:  35  Loss:  1.00021493434906  AUC Score:  62.44090441932168
# Epoch:  36  Loss:  1.000205636024475  AUC Score:  62.439619732785204
# Epoch:  37  Loss:  1.0001850128173828  AUC Score:  62.43961973278521
# Epoch:  38  Loss:  1.0001577138900757  AUC Score:  62.45632065775951
# Epoch:  39  Loss:  1.0001276731491089  AUC Score:  62.45889003083247
# Epoch:  40  Loss:  1.0000972747802734  AUC Score:  62.460174717368965
# Epoch:  41  Loss:  1.0000680685043335  AUC Score:  62.41135662898253
# Epoch:  42  Loss:  1.0000410079956055  AUC Score:  62.47045220966084
# Epoch:  43  Loss:  1.0000163316726685  AUC Score:  62.54881808838644
# Epoch:  44  Loss:  0.9999964237213135  AUC Score:  37.160842754367934
# Epoch:  45  Loss:  0.9999814033508301  AUC Score:  37.55395683453238
# Epoch:  46  Loss:  0.9999725818634033  AUC Score:  37.47816032887975
# Epoch:  47  Loss:  1.0  AUC Score:  50.0
# Epoch:  48  Loss:  1.0  AUC Score:  50.0
# Epoch:  49  Loss:  1.0  AUC Score:  50.0
# Epoch:  50  Loss:  1.0  AUC Score:  50.0
# Epoch:  51  Loss:  1.0  AUC Score:  50.0
# Epoch:  52  Loss:  1.0  AUC Score:  50.0
# Epoch:  53  Loss:  1.0  AUC Score:  50.0
# Epoch:  54  Loss:  1.0  AUC Score:  50.0
# Epoch:  55  Loss:  1.0  AUC Score:  50.0
# Epoch:  56  Loss:  1.0  AUC Score:  50.0
# Epoch:  57  Loss:  1.0  AUC Score:  50.0
# Epoch:  58  Loss:  1.0  AUC Score:  50.0
# Epoch:  59  Loss:  1.0  AUC Score:  50.0
# Epoch:  60  Loss:  1.0  AUC Score:  50.0
# Epoch:  61  Loss:  1.0  AUC Score:  50.0
# Epoch:  62  Loss:  1.0  AUC Score:  50.0
# Epoch:  63  Loss:  1.0  AUC Score:  50.0
# Epoch:  64  Loss:  1.0  AUC Score:  50.0
# Epoch:  65  Loss:  1.0  AUC Score:  50.0
# Epoch:  66  Loss:  1.0  AUC Score:  50.0
# Epoch:  67  Loss:  1.0  AUC Score:  50.0
# Epoch:  68  Loss:  1.0  AUC Score:  50.0
# Epoch:  69  Loss:  1.0  AUC Score:  50.0
# Epoch:  70  Loss:  1.0  AUC Score:  50.0
# Epoch:  71  Loss:  0.9999995231628418  AUC Score:  37.94578622816033
# Epoch:  72  Loss:  0.9999995231628418  AUC Score:  38.620246659815
# Epoch:  73  Loss:  0.9999995231628418  AUC Score:  38.934994861253855
# Epoch:  74  Loss:  1.0  AUC Score:  38.99922918807811
# Epoch:  75  Loss:  1.0  AUC Score:  39.09558067831449
# Epoch:  76  Loss:  0.9999997615814209  AUC Score:  38.89131551901336
# Epoch:  77  Loss:  1.0  AUC Score:  36.79727646454265
# Epoch:  78  Loss:  0.9999997615814209  AUC Score:  39.09815005138746
# Epoch:  79  Loss:  0.9999997615814209  AUC Score:  39.14311408016444
# Epoch:  80  Loss:  1.0  AUC Score:  39.140544707091465
# Epoch:  81  Loss:  1.0  AUC Score:  40.48304213771839
# Epoch:  82  Loss:  1.0  AUC Score:  40.48304213771839
# Epoch:  83  Loss:  1.0  AUC Score:  40.5344295991778
# Epoch:  84  Loss:  1.0  AUC Score:  40.48304213771839
# Epoch:  85  Loss:  1.0  AUC Score:  50.0
# Epoch:  86  Loss:  1.0  AUC Score:  50.0
# Epoch:  87  Loss:  1.0  AUC Score:  40.48304213771839
# Epoch:  88  Loss:  1.0  AUC Score:  50.0
# Epoch:  89  Loss:  1.0  AUC Score:  50.0
# Epoch:  90  Loss:  1.0  AUC Score:  50.07194244604316
# Epoch:  91  Loss:  1.0  AUC Score:  50.0
# Epoch:  92  Loss:  1.0  AUC Score:  50.0
# Epoch:  93  Loss:  1.0  AUC Score:  50.0
# Epoch:  94  Loss:  1.0  AUC Score:  50.0
# Epoch:  95  Loss:  1.0  AUC Score:  50.0
# Epoch:  96  Loss:  1.0  AUC Score:  50.0
# Epoch:  97  Loss:  1.0  AUC Score:  50.0
# Epoch:  98  Loss:  1.0  AUC Score:  50.0
# Epoch:  99  Loss:  1.0  AUC Score:  50.0
# Maximum AUC:  62.54881808838644
# Required Time:  1.3601713180541992
# ____________________________________________________________________________________________________
# dataset: weibo
# ____________________________________________________________________________________________________
# Epoch:  0  Loss:  1.165885329246521  AUC Score:  47.695418589863266
# Epoch:  1  Loss:  1.4258180856704712  AUC Score:  58.53541650125924
# Epoch:  2  Loss:  0.8832032680511475  AUC Score:  35.12990830885304
# Epoch:  3  Loss:  1.1005433797836304  AUC Score:  56.473134615535926
# Epoch:  4  Loss:  1.1826801300048828  AUC Score:  78.91427281889301
# Epoch:  5  Loss:  0.9263191223144531  AUC Score:  31.026910089173377
# Epoch:  6  Loss:  0.9905149936676025  AUC Score:  31.921004275200758
# Epoch:  7  Loss:  1.0  AUC Score:  50.0
# Epoch:  8  Loss:  1.0000267028808594  AUC Score:  50.0
# Epoch:  9  Loss:  1.1053365468978882  AUC Score:  65.19910046972133
# Epoch:  10  Loss:  1.0653592348098755  AUC Score:  67.7906503498054
# Epoch:  11  Loss:  1.0034445524215698  AUC Score:  84.53946639028428
# Epoch:  12  Loss:  0.9991660118103027  AUC Score:  25.38699972748009
# Epoch:  13  Loss:  1.014467716217041  AUC Score:  44.29036817368031
# Epoch:  14  Loss:  1.0188106298446655  AUC Score:  50.92713990714296
# Epoch:  15  Loss:  1.0001907348632812  AUC Score:  50.14409221902017
# Epoch:  16  Loss:  1.0  AUC Score:  50.0
# Epoch:  17  Loss:  1.0  AUC Score:  50.0
# Epoch:  18  Loss:  1.0  AUC Score:  50.0
# Epoch:  19  Loss:  1.0  AUC Score:  50.0
# Epoch:  20  Loss:  0.9930729866027832  AUC Score:  40.093794056491014
# Epoch:  21  Loss:  0.998523473739624  AUC Score:  17.178821698306873
# Epoch:  22  Loss:  1.0018061399459839  AUC Score:  12.57076755482407
# Epoch:  23  Loss:  1.0009557008743286  AUC Score:  40.49681595178472
# Epoch:  24  Loss:  0.9994256496429443  AUC Score:  57.29126655951842
# Epoch:  25  Loss:  1.0  AUC Score:  50.0
# Epoch:  26  Loss:  1.0  AUC Score:  50.0
# Epoch:  27  Loss:  1.0  AUC Score:  50.0
# Epoch:  28  Loss:  1.0  AUC Score:  50.0
# Epoch:  29  Loss:  1.0  AUC Score:  50.0
# Epoch:  30  Loss:  0.9999873638153076  AUC Score:  18.025171254800394
# Epoch:  31  Loss:  1.0002164840698242  AUC Score:  26.947283491516476
# Epoch:  32  Loss:  1.000089406967163  AUC Score:  37.529120647638905
# Epoch:  33  Loss:  1.0002682209014893  AUC Score:  43.66568244778669
# Epoch:  34  Loss:  1.0005301237106323  AUC Score:  42.22812205172442
# Epoch:  35  Loss:  1.0  AUC Score:  50.0
# Epoch:  36  Loss:  1.0  AUC Score:  50.0
# Epoch:  37  Loss:  1.0  AUC Score:  50.0
# Epoch:  38  Loss:  1.0  AUC Score:  50.0
# Epoch:  39  Loss:  1.0  AUC Score:  50.0
# Epoch:  40  Loss:  0.9998683929443359  AUC Score:  65.56521415701582
# Epoch:  41  Loss:  1.000038981437683  AUC Score:  45.890367601460014
# Epoch:  42  Loss:  1.0000449419021606  AUC Score:  44.93973089910826
# Epoch:  43  Loss:  0.9999608993530273  AUC Score:  61.52313951517206
# Epoch:  44  Loss:  1.0  AUC Score:  50.0
# Epoch:  45  Loss:  1.0  AUC Score:  50.0
# Epoch:  46  Loss:  1.0  AUC Score:  50.0
# Epoch:  47  Loss:  1.0  AUC Score:  50.0
# Epoch:  48  Loss:  1.0  AUC Score:  50.0
# Epoch:  49  Loss:  1.0  AUC Score:  45.04235502978048
# Epoch:  50  Loss:  0.9999527931213379  AUC Score:  62.440354976850124
# Epoch:  51  Loss:  0.999967098236084  AUC Score:  64.42633486473785
# Epoch:  52  Loss:  0.9999933242797852  AUC Score:  74.5868927222879
# Epoch:  53  Loss:  1.0  AUC Score:  50.0
# Epoch:  54  Loss:  1.0  AUC Score:  50.0
# Epoch:  55  Loss:  1.0  AUC Score:  50.0
# Epoch:  56  Loss:  1.0  AUC Score:  50.0
# Epoch:  57  Loss:  1.0  AUC Score:  50.0
# Epoch:  58  Loss:  1.0  AUC Score:  50.74699781054215
# Epoch:  59  Loss:  0.9999940395355225  AUC Score:  62.370991149898124
# Epoch:  60  Loss:  0.9999885559082031  AUC Score:  61.50447082856781
# Epoch:  61  Loss:  0.9999942779541016  AUC Score:  63.013344176907616
# Epoch:  62  Loss:  1.0  AUC Score:  50.0
# Epoch:  63  Loss:  1.0  AUC Score:  50.0
# Epoch:  64  Loss:  1.0  AUC Score:  50.0
# Epoch:  65  Loss:  1.0  AUC Score:  50.0
# Epoch:  66  Loss:  1.000000238418579  AUC Score:  36.92133330186122
# Epoch:  67  Loss:  1.0  AUC Score:  50.0
# Epoch:  68  Loss:  1.000000238418579  AUC Score:  35.73853610316559
# Epoch:  69  Loss:  1.0  AUC Score:  40.68554135257138
# Epoch:  70  Loss:  1.0  AUC Score:  50.0
# Epoch:  71  Loss:  1.0  AUC Score:  50.0
# Epoch:  72  Loss:  1.0  AUC Score:  50.0
# Epoch:  73  Loss:  1.0  AUC Score:  50.0
# Epoch:  74  Loss:  1.0  AUC Score:  61.15874248871474
# Epoch:  75  Loss:  1.0  AUC Score:  50.0
# Epoch:  76  Loss:  1.0  AUC Score:  40.216714125186066
# Epoch:  77  Loss:  1.0  AUC Score:  40.410464335298194
# Epoch:  78  Loss:  1.0  AUC Score:  50.0
# Epoch:  79  Loss:  1.0  AUC Score:  50.0
# Epoch:  80  Loss:  1.0  AUC Score:  50.0
# Epoch:  81  Loss:  1.0  AUC Score:  50.0
# Epoch:  82  Loss:  1.0  AUC Score:  50.0
# Epoch:  83  Loss:  1.0  AUC Score:  50.0
# Epoch:  84  Loss:  1.0  AUC Score:  50.0
# Epoch:  85  Loss:  1.0  AUC Score:  51.72223998489338
# Epoch:  86  Loss:  1.0  AUC Score:  50.0
# Epoch:  87  Loss:  1.0  AUC Score:  50.0
# Epoch:  88  Loss:  1.0  AUC Score:  50.0
# Epoch:  89  Loss:  1.0  AUC Score:  50.0
# Epoch:  90  Loss:  1.0  AUC Score:  50.0
# Epoch:  91  Loss:  1.0  AUC Score:  50.0
# Epoch:  92  Loss:  1.0  AUC Score:  50.0
# Epoch:  93  Loss:  1.0  AUC Score:  50.0
# Epoch:  94  Loss:  1.0  AUC Score:  50.0
# Epoch:  95  Loss:  1.0  AUC Score:  50.0
# Epoch:  96  Loss:  1.0  AUC Score:  50.0
# Epoch:  97  Loss:  1.0  AUC Score:  50.0
# Epoch:  98  Loss:  1.0  AUC Score:  50.0
# Epoch:  99  Loss:  1.0  AUC Score:  50.0
# Epoch:  100  Loss:  1.0  AUC Score:  50.0
# Epoch:  101  Loss:  1.0  AUC Score:  50.0
# Epoch:  102  Loss:  1.0  AUC Score:  50.0
# Epoch:  103  Loss:  1.0  AUC Score:  50.0
# Epoch:  104  Loss:  1.0  AUC Score:  50.0
# Epoch:  105  Loss:  1.0  AUC Score:  50.0
# Epoch:  106  Loss:  1.0  AUC Score:  50.0
# Epoch:  107  Loss:  1.0  AUC Score:  50.0
# Epoch:  108  Loss:  1.0  AUC Score:  50.0
# Epoch:  109  Loss:  1.0  AUC Score:  50.0
# Epoch:  110  Loss:  1.0  AUC Score:  50.0
# Epoch:  111  Loss:  1.0  AUC Score:  50.0
# Epoch:  112  Loss:  1.0  AUC Score:  50.0
# Epoch:  113  Loss:  1.0  AUC Score:  50.0
# Epoch:  114  Loss:  1.0  AUC Score:  50.0
# Epoch:  115  Loss:  1.0  AUC Score:  50.0
# Epoch:  116  Loss:  1.0  AUC Score:  50.0
# Epoch:  117  Loss:  1.0  AUC Score:  50.0
# Epoch:  118  Loss:  1.0  AUC Score:  50.0
# Epoch:  119  Loss:  1.0  AUC Score:  50.0
# Epoch:  120  Loss:  1.0  AUC Score:  50.0
# Epoch:  121  Loss:  1.0  AUC Score:  50.0
# Epoch:  122  Loss:  1.0  AUC Score:  50.0
# Epoch:  123  Loss:  1.0  AUC Score:  50.0
# Epoch:  124  Loss:  1.0  AUC Score:  50.0
# Epoch:  125  Loss:  1.0  AUC Score:  50.0
# Epoch:  126  Loss:  1.0  AUC Score:  50.0
# Epoch:  127  Loss:  1.0  AUC Score:  50.0
# Epoch:  128  Loss:  1.0  AUC Score:  50.0
# Epoch:  129  Loss:  1.0  AUC Score:  50.0
# Epoch:  130  Loss:  1.0  AUC Score:  50.0
# Epoch:  131  Loss:  1.0  AUC Score:  50.0
# Epoch:  132  Loss:  1.0  AUC Score:  50.0
# Epoch:  133  Loss:  1.0  AUC Score:  50.0
# Epoch:  134  Loss:  1.0  AUC Score:  50.0
# Epoch:  135  Loss:  1.0  AUC Score:  50.0
# Epoch:  136  Loss:  1.0  AUC Score:  50.0
# Epoch:  137  Loss:  1.0  AUC Score:  50.0
# Epoch:  138  Loss:  1.0  AUC Score:  50.0
# Epoch:  139  Loss:  1.0  AUC Score:  50.0
# Epoch:  140  Loss:  1.0  AUC Score:  50.0
# Epoch:  141  Loss:  1.0  AUC Score:  50.0
# Epoch:  142  Loss:  1.0  AUC Score:  50.0
# Epoch:  143  Loss:  1.0  AUC Score:  50.0
# Epoch:  144  Loss:  1.0  AUC Score:  50.0
# Epoch:  145  Loss:  1.0  AUC Score:  50.0
# Epoch:  146  Loss:  1.0  AUC Score:  50.0
# Epoch:  147  Loss:  1.0  AUC Score:  50.0
# Epoch:  148  Loss:  1.0  AUC Score:  50.0
# Epoch:  149  Loss:  1.0  AUC Score:  50.0
# Epoch:  150  Loss:  1.0  AUC Score:  50.0
# Epoch:  151  Loss:  1.0  AUC Score:  50.0
# Epoch:  152  Loss:  1.0  AUC Score:  50.0
# Epoch:  153  Loss:  1.0  AUC Score:  50.0
# Epoch:  154  Loss:  1.0  AUC Score:  50.0
# Epoch:  155  Loss:  1.0  AUC Score:  50.0
# Epoch:  156  Loss:  1.0  AUC Score:  50.0
# Epoch:  157  Loss:  1.0  AUC Score:  50.0
# Epoch:  158  Loss:  1.0  AUC Score:  50.0
# Epoch:  159  Loss:  1.0  AUC Score:  50.0
# Epoch:  160  Loss:  1.0  AUC Score:  50.0
# Epoch:  161  Loss:  1.0  AUC Score:  50.0
# Epoch:  162  Loss:  1.0  AUC Score:  50.0
# Epoch:  163  Loss:  1.0  AUC Score:  50.0
# Epoch:  164  Loss:  1.0  AUC Score:  50.0
# Epoch:  165  Loss:  1.0  AUC Score:  50.0
# Epoch:  166  Loss:  1.0  AUC Score:  50.0
# Epoch:  167  Loss:  1.0  AUC Score:  50.0
# Epoch:  168  Loss:  1.0  AUC Score:  50.0
# Epoch:  169  Loss:  1.0  AUC Score:  50.0
# Epoch:  170  Loss:  1.0  AUC Score:  50.0
# Epoch:  171  Loss:  1.0  AUC Score:  50.0
# Epoch:  172  Loss:  1.0  AUC Score:  50.0
# Epoch:  173  Loss:  1.0  AUC Score:  50.0
# Epoch:  174  Loss:  1.0  AUC Score:  50.0
# Epoch:  175  Loss:  1.0  AUC Score:  50.0
# Epoch:  176  Loss:  1.0  AUC Score:  50.0
# Epoch:  177  Loss:  1.0  AUC Score:  50.0
# Epoch:  178  Loss:  1.0  AUC Score:  50.0
# Epoch:  179  Loss:  1.0  AUC Score:  50.0
# Epoch:  180  Loss:  1.0  AUC Score:  50.0
# Epoch:  181  Loss:  1.0  AUC Score:  50.0
# Epoch:  182  Loss:  1.0  AUC Score:  50.0
# Epoch:  183  Loss:  1.0  AUC Score:  50.0
# Epoch:  184  Loss:  1.0  AUC Score:  50.0
# Epoch:  185  Loss:  1.0  AUC Score:  50.0
# Epoch:  186  Loss:  1.0  AUC Score:  50.0
# Epoch:  187  Loss:  1.0  AUC Score:  50.0
# Epoch:  188  Loss:  1.0  AUC Score:  50.0
# Epoch:  189  Loss:  1.0  AUC Score:  50.0
# Epoch:  190  Loss:  1.0  AUC Score:  50.0
# Epoch:  191  Loss:  1.0  AUC Score:  50.0
# Epoch:  192  Loss:  1.0  AUC Score:  50.0
# Epoch:  193  Loss:  1.0  AUC Score:  50.0
# Epoch:  194  Loss:  1.0  AUC Score:  50.0
# Epoch:  195  Loss:  1.0  AUC Score:  50.0
# Epoch:  196  Loss:  1.0  AUC Score:  50.0
# Epoch:  197  Loss:  1.0  AUC Score:  50.0
# Epoch:  198  Loss:  1.0  AUC Score:  50.0
# Epoch:  199  Loss:  1.0  AUC Score:  50.0
# Maximum AUC:  84.53946639028428
# Required Time:  144.64029502868652
